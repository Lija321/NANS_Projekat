# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sb
import utils_nans1 as un
from sklearn.linear_model import HuberRegressor


# Suppress warnings
import warnings 
warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', None)
from IPython.display import display
from scipy import stats

# %%
df_x=pd.read_csv('parsed_data/podaci_za_predvidjanje.csv')
df_y=pd.read_csv('parsed_data/predvidjanja.csv')

df_x.sort_values(by=['game_id'], inplace=True)
df_y.sort_values(by=['game_id'], inplace=True)

df_x.drop(['game_id'], axis=1, inplace=True)
df_x.drop(['team_id'], axis=1, inplace=True)
df_x.drop(['opponent'], axis=1, inplace=True)
df_x.drop(['opponent_previous_game'], axis=1, inplace=True)
df_y.drop(['game_id'], axis=1, inplace=True)

display(df_x.head(), df_y.head())
# Out:
#    points_scored  fast_break_points_for  fast_break_points_against  \
# 0             66                      2                          5
# 1             63                      2                          4
# 2             73                     13                          4
# 3             99                      6                          4
# 4             97                      4                          6
#
#    turnover_points_for  turnover_points_against  second_chance_points_for  \
# 0                    7                        4                         2
# 1                   11                       13                        14
# 2                   18                       11                        10
# 3                   14                       10                        22
# 4                   10                       14                        16
#
#    second_chance_points_against  defensive_rebounds_for  \
# 0                            10                      28
# 1                            15                      27
# 2                            15                      23
# 3                            16                      21
# 4                            22                      22
#
#    defensive_rebounds_against  offensive_rebounds_for  \
# 0                          26                       7
# 1                          22                      12
# 2                          24                       6
# 3                          22                      13
# 4                          21                      11
#
#    offensive_rebounds_against  turnovers_for  turnovers_against  steals_for  \
# 0                           7             11                  9           5
# 1                          12             15                 11           3
# 2                           9             11                 16           9
# 3                          11              9                 12           6
# 4                          13             12                  9           3
#
#    steals_against  assists_for  assists_against    3P%_for  3P%_against  \
# 0               5           17               16  37.745569    37.745569
# 1              10           17               20  37.745569    37.745569
# 2               4           12               17  34.285714    47.368421
# 3               3           29               15  47.368421    34.285714
# 4               6           15               29  37.745569    37.745569
#
#      2P%_for  2P%_against    FT%_for    PFR_for  PFD_against    3PR_for  \
# 0  51.864171    51.864171  75.662177  29.706255    29.436574  36.961091
# 1  51.864171    51.864171  75.662177  29.706255    29.436574  36.961091
# 2  56.666667    51.219512  76.923077  26.455026    23.809524  53.846154
# 3  51.219512    56.666667  70.588235  25.132275    26.455026  31.666667
# 4  51.864171    51.864171  75.662177  29.706255    29.436574  36.961091
#
#    3PR_against    FTR_for  FTR_against       PACE        ORtg        DRtg  \
# 0    36.961091  32.024197    32.024197  71.726654  110.499731  110.499731
# 1    36.961091  32.024197    32.024197  71.726654  110.499731  110.499731
# 2    31.666667  20.000000    28.333333  75.600000  105.820106  107.142857
# 3    53.846154  28.333333    20.000000  75.600000  107.142857  105.820106
# 4    36.961091  32.024197    32.024197  71.726654  110.499731  110.499731
#
#         eFG%        TS%  opponent_steals_for  opponent_steals_against  \
# 0  53.592021  57.545070                  3.0                     10.0
# 1  53.592021  57.545070                  5.0                      5.0
# 2  53.846154  56.561086                  6.0                      3.0
# 3  57.500000  60.017783                  9.0                      4.0
# 4  53.592021  57.545070                  6.0                      4.0
#
#    opponent_defensive_rebounds_for  opponent_defensive_rebounds_against  \
# 0                             27.0                                 22.0
# 1                             28.0                                 26.0
# 2                             21.0                                 22.0
# 3                             23.0                                 24.0
# 4                             29.0                                 25.0
#
#    opponent_offensive_rebounds_for  opponent_offensive_rebounds_against  \
# 0                             12.0                                 12.0
# 1                              7.0                                  7.0
# 2                             13.0                                 11.0
# 3                              6.0                                  9.0
# 4                             10.0                                 10.0
#
#    opponent_turnovers_for  opponent_turnovers_against  opponent_PFD_for  \
# 0                    15.0                        11.0         29.197324
# 1                    11.0                         9.0         24.195844
# 2                     9.0                        12.0         23.535565
# 3                    11.0                        16.0         29.197324
# 4                    10.0                        12.0         29.197324
#
#    opponent_PFD_against  opponent_PACE  opponent_ORtg  opponent_DRtg
# 0             29.710963      71.904855     111.232130     110.718735
# 1             29.888984      70.260000     105.323086     111.016225
# 2             20.920502      76.480000      91.527197     108.525105
# 3             29.710963      71.904855     111.232130     110.718735
# 4             29.710963      71.904855     111.232130     110.718735
#    score
# 0     89
# 1     86
# 2     80
# 3     81
# 4     82

# %%
x_with_const=sm.add_constant(df_x)
model=sm.OLS(df_y, x_with_const).fit()

plt.figure(figsize=(26,16))

correration_matrix=df_x.corr()
sb.heatmap(correration_matrix, annot=True,cmap='coolwarm',fmt='.2f',linewidths=0.1)
plt.show()

# %% [markdown]
# ### Analiza koreleacija izmedju parametara
# Postoji znacjna koreleacija izmedju:
# * offensive_rebounds_for i second_chance_points_for
# * offensive_rebounds_against i second_chance_points_against
# * turnovers_for i turnover_points_against
# * turnovers_against i turnover_points_for
# * steals_for i turnover_points_for
# * steals_against i turnover_points_against
# * steals_for i turnovers_against
# * steals_against i turnovers_for

# %%
#df_x.drop(['second_chance_points_for'], axis=1, inplace=True)
#df_x.drop(['second_chance_points_against'], axis=1, inplace=True)
#df_x.drop(['turnover_points_against'], axis=1, inplace=True)
#df_x.drop(['turnover_points_for'], axis=1, inplace=True)

#df_x.drop(['turnovers_against'], axis=1, inplace=True)
#df_x.drop(['turnovers_for'], axis=1, inplace=True)

#df_x.drop(['PFD_against'], axis=1, inplace=True)
#df_x.drop(['PFR_for'], axis=1, inplace=True)
df_x.drop(['eFG%'], axis=1, inplace=True)
#df_x.drop(['TS%'], axis=1, inplace=True)
#df_x.drop(['ORtg'], axis=1, inplace=True)
#df_x.drop(['DRtg'], axis=1, inplace=True)
#df_x.drop(['assists_for'], axis=1, inplace=True)

x_with_const=sm.add_constant(df_x)
model=sm.OLS(df_y, x_with_const).fit()

plt.figure(figsize=(26,16))

correration_matrix=df_x.corr()
sb.heatmap(correration_matrix, annot=True,cmap='coolwarm',fmt='.2f',linewidths=0.1)
plt.show()

# %% [markdown]
# ### Izbaceni parametri sa visokom korelacijom

# %%
def box_plot(df, column):
    df.boxplot(column=column)
    plt.grid(False)
    plt.show()

def outliers(df, column):
    Q1 = df[column].quantile(0.10)
    Q3 = df[column].quantile(0.90)
    IQR = Q3 - Q1
    return df[(df[column] < Q1 - 1.5 * IQR) | (df[column] > Q3 + 1.5 * IQR)]

# %%
df_x['y']=df_y
df_x.head()

index_list=[]
for column in df_x.columns:
    if column!='y':
        index_list.extend(outliers(df_x, column).index.tolist())
index_set=set(index_list)

for i in index_set:
    df_x.drop(i, inplace=True)
    df_y.drop(i, inplace=True)

df_x=df_x.drop(['y'], axis=1)

# %%
df_x_train, df_x_test, df_y_train, df_y_test=train_test_split(df_x, df_y, test_size=0.2, random_state=42)
un.are_assumptions_satisfied(model, df_x_train, df_y_train.values.ravel(), p_value_thresh=0.05)
# Out:
# Autocorrelation assumption is not satisfied.
# False

# %% [markdown]
# ## T-test

# %%
# pomocna funkcija koja vraca fitovan model``
def get_fitted_model(x, y):
    x_with_const = sm.add_constant(x)
    model = sm.OLS(y, x_with_const).fit()
    return model


noncolinearl_model=get_fitted_model(df_x_train, df_y_train)
print(noncolinearl_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     2.148
# Date:                Wed, 31 Jan 2024   Prob (F-statistic):           3.54e-05
# Time:                        21:35:11   Log-Likelihood:                -2476.2
# No. Observations:                 668   AIC:                             5044.
# Df Residuals:                     622   BIC:                             5252.
# Df Model:                          45
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -48.8263     30.229     -1.615      0.107    -108.190      10.537
# points_scored                           0.0054      0.058      0.093      0.926      -0.109       0.120
# fast_break_points_for                  -0.0032      0.101     -0.032      0.975      -0.202       0.196
# fast_break_points_against               0.0138      0.102      0.135      0.893      -0.187       0.214
# turnover_points_for                     0.0359      0.108      0.333      0.740      -0.176       0.248
# turnover_points_against                -0.0677      0.108     -0.629      0.529      -0.279       0.144
# second_chance_points_for                0.1251      0.126      0.992      0.322      -0.123       0.373
# second_chance_points_against           -0.1536      0.124     -1.243      0.214      -0.396       0.089
# defensive_rebounds_for                  0.0004      0.125      0.003      0.998      -0.245       0.246
# defensive_rebounds_against              0.1135      0.140      0.813      0.417      -0.161       0.388
# offensive_rebounds_for                  0.0950      0.165      0.575      0.566      -0.229       0.419
# offensive_rebounds_against              0.1812      0.160      1.130      0.259      -0.134       0.496
# turnovers_for                           0.2509      0.230      1.090      0.276      -0.201       0.703
# turnovers_against                      -0.2253      0.217     -1.038      0.299      -0.651       0.201
# steals_for                              0.0177      0.226      0.078      0.938      -0.427       0.462
# steals_against                         -0.2121      0.234     -0.908      0.364      -0.671       0.247
# assists_for                             0.1178      0.120      0.983      0.326      -0.117       0.353
# assists_against                         0.1023      0.110      0.932      0.352      -0.113       0.318
# 3P%_for                                -0.1975      0.363     -0.544      0.587      -0.911       0.516
# 3P%_against                            -0.1371      0.100     -1.371      0.171      -0.333       0.059
# 2P%_for                                -0.3135      0.426     -0.735      0.463      -1.151       0.524
# 2P%_against                            -0.0102      0.131     -0.078      0.938      -0.268       0.247
# FT%_for                                -0.0235      0.121     -0.194      0.846      -0.262       0.215
# PFR_for                                 0.2639      0.248      1.066      0.287      -0.222       0.750
# PFD_against                            -0.1472      0.271     -0.543      0.587      -0.680       0.385
# 3PR_for                                 0.0270      0.119      0.227      0.821      -0.207       0.261
# 3PR_against                            -0.0349      0.117     -0.299      0.765      -0.264       0.194
# FTR_for                                -0.0534      0.134     -0.398      0.691      -0.317       0.210
# FTR_against                            -0.0558      0.105     -0.531      0.595      -0.262       0.150
# PACE                                    0.8571      0.247      3.466      0.001       0.371       1.343
# ORtg                                    0.3651      0.107      3.401      0.001       0.154       0.576
# DRtg                                    0.0584      0.096      0.606      0.545      -0.131       0.248
# TS%                                     0.4675      0.798      0.586      0.558      -1.100       2.035
# opponent_steals_for                    -0.3096      0.226     -1.367      0.172      -0.754       0.135
# opponent_steals_against                -0.4094      0.226     -1.815      0.070      -0.852       0.033
# opponent_defensive_rebounds_for         0.1633      0.103      1.582      0.114      -0.039       0.366
# opponent_defensive_rebounds_against     0.1528      0.104      1.470      0.142      -0.051       0.357
# opponent_offensive_rebounds_for         0.1824      0.112      1.628      0.104      -0.038       0.403
# opponent_offensive_rebounds_against     0.0687      0.114      0.604      0.546      -0.155       0.292
# opponent_turnovers_for                  0.1121      0.184      0.611      0.541      -0.248       0.473
# opponent_turnovers_against             -0.1939      0.182     -1.064      0.288      -0.552       0.164
# opponent_PFD_for                       -0.2415      0.170     -1.419      0.157      -0.576       0.093
# opponent_PFD_against                    0.2047      0.158      1.293      0.196      -0.106       0.516
# opponent_PACE                          -0.1196      0.190     -0.630      0.529      -0.493       0.253
# opponent_ORtg                           0.0646      0.061      1.064      0.288      -0.055       0.184
# opponent_DRtg                           0.1327      0.062      2.139      0.033       0.011       0.255
# ==============================================================================
# Omnibus:                        0.265   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.876   Jarque-Bera (JB):                0.189
# Skew:                          -0.037   Prob(JB):                        0.910
# Kurtosis:                       3.037   Cond. No.                     2.37e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Analiza t-testa
# Parametri ciji je p-value veci od 0.05 su:

# %%
df_x_ttested=df_x_train.copy()

df_x_ttested.drop(['defensive_rebounds_for'], axis=1, inplace=True)
df_x_ttested.drop(['second_chance_points_for'], axis=1, inplace=True)
df_x_ttested.drop(['second_chance_points_against'], axis=1, inplace=True)
df_x_ttested.drop(['turnover_points_against'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_turnovers_for'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_turnovers_against'], axis=1, inplace=True)
df_x_ttested.drop(['FTR_against'], axis=1, inplace=True)
df_x_ttested.drop(['steals_for'], axis=1, inplace=True)
df_x_ttested.drop(['fast_break_points_for'], axis=1, inplace=True)
df_x_ttested.drop(['fast_break_points_against'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_ORtg'], axis=1, inplace=True)
df_x_ttested.drop(['TS%'], axis=1, inplace=True)
df_x_ttested.drop(['3PR_against'], axis=1, inplace=True)
df_x_ttested.drop(['offensive_rebounds_against'], axis=1, inplace=True)
df_x_ttested.drop(['turnovers_for'], axis=1, inplace=True)
df_x_ttested.drop(['turnover_points_for'], axis=1, inplace=True)
df_x_ttested.drop(['DRtg'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_PFD_for'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_PACE'], axis=1, inplace=True)
df_x_ttested.drop(['PFR_for'], axis=1, inplace=True)
df_x_ttested.drop(['2P%_against'], axis=1, inplace=True)
df_x_ttested.drop(['assists_against'], axis=1, inplace=True)
df_x_ttested.drop(['FTR_for'], axis=1, inplace=True)

df_x_ttested.drop(['3P%_for'], axis=1, inplace=True)
df_x_ttested.drop(['3P%_against'], axis=1, inplace=True)
df_x_ttested.drop(['2P%_for'], axis=1, inplace=True)
df_x_ttested.drop(['3PR_for'], axis=1, inplace=True)
df_x_ttested.drop(['points_scored'], axis=1, inplace=True)
df_x_ttested.drop(['steals_against'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_PFD_against'], axis=1, inplace=True)
df_x_ttested.drop(['PFD_against'], axis=1, inplace=True)
df_x_ttested.drop(['FT%_for'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_defensive_rebounds_for'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_defensive_rebounds_against'], axis=1, inplace=True)
df_x_ttested.drop(['defensive_rebounds_against'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_steals_for'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_offensive_rebounds_against'], axis=1, inplace=True)  
df_x_ttested.drop(['assists_for'], axis=1, inplace=True) 
df_x_ttested.drop(['turnovers_against'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_DRtg'], axis=1, inplace=True)
df_x_ttested.drop(['opponent_steals_against'], axis=1, inplace=True)

noncolinearl_model=get_fitted_model(df_x_ttested, df_y_train)
print(noncolinearl_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     12.05
# Date:                Wed, 31 Jan 2024   Prob (F-statistic):           1.86e-09
# Time:                        21:35:11   Log-Likelihood:                -2501.0
# No. Observations:                 668   AIC:                             5012.
# Df Residuals:                     663   BIC:                             5035.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                             -14.9745     16.642     -0.900      0.369     -47.652      17.703
# offensive_rebounds_for              0.1684      0.110      1.537      0.125      -0.047       0.383
# PACE                                0.7020      0.199      3.531      0.000       0.312       1.092
# ORtg                                0.3743      0.062      6.037      0.000       0.253       0.496
# opponent_offensive_rebounds_for     0.1440      0.108      1.329      0.184      -0.069       0.357
# ==============================================================================
# Omnibus:                        1.017   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.602   Jarque-Bera (JB):                0.854
# Skew:                           0.033   Prob(JB):                        0.653
# Kurtosis:                       3.162   Cond. No.                     5.56e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.56e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
noncolinearl_model.f_pvalue
# Out:
# 1.8585857945956467e-09

# %% [markdown]
# Vrednost f-testa je manja od 0.05, tako da postoji linearna veza $Y$ sa bar jednom od $X$ varijabli.
# Takodje  Durbin-Watson statistika je izmedju 1.5 i 2, sto znaci da nema autokorelacije.

# %%
residuals=noncolinearl_model.resid
#print(residuals)
# mean absolute error
import numpy as np
mae = np.mean(np.abs(residuals))
print(mae)
# Out:
# 7.9777435971216475
